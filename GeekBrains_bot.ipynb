# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter,MarkdownHeaderTextSplitter
from langchain.chains import VectorDBQA
from langchain.document_loaders import TextLoader,DirectoryLoader
from sentence_transformers import SentenceTransformer
import requests
import json
import os 
import re
import numpy as np
import faiss
import pickle
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.retrievers import BM25Retriever, EnsembleRetriever
from langchain.vectorstores.faiss import FAISS

# %%
from PyPDF2 import PdfReader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, HuggingFaceInstructEmbeddings,HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.llms import HuggingFaceHub
from tqdm.auto import tqdm

# %%
def get_pdf_text(pdf_docs):
    texts = []
    attribute = []
    for pdf in tqdm(pdf_docs):
        text = ''
        pdf_reader = PdfReader(pdf)
        for page in pdf_reader.pages:
            text += page.extract_text()
        texts.append(text)
    return texts
    
def get_text_chunks(text):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=512,
        chunk_overlap=128,
        length_function=len
            )
    chunks = text_splitter.split_documents(text)
    return chunks

# %%
#import streamlit as st
#@st.cache_data
def load_faiss_index():
    with open('chunks_gb.pickle', 'rb') as handle:
        chunks = pickle.load(handle)

    model = SentenceTransformer('BAAI/bge-m3',device="cpu")
    embeddings = np.load('embs-gb.npy')

    index = faiss.IndexFlatL2(embeddings.shape[1])   # build the index
    index.add(embeddings)     

    return chunks, model, index, embeddings

def get_relevant_documents(question, chunks, model, index, embeddings):
    k = 3 #NUM of retrieval candidates
    e = model.encode(question)
    dist, Idx = index.search(e.reshape(1,-1), k)
    retrievals = [chunks[i] for i in Idx.flatten()]
    return retrievals

# %%
def generate_mixtral_response(question, chunks, model, index, embeddings):
    rets = get_relevant_documents(question, chunks, model, index, embeddings)
    metadatas = [list(item.metadata.keys())[0] for item in rets]
    
    # Improved string formatting
    sources_text = ' \n\n '.join([f'ИСТОЧНИК {i+1}: {ret.page_content}' for i, ret in enumerate(rets)])
    
    promptstring = (
        f"Вы программист, который точно отвечает на вопросы пользователей на темы, связанные с программированием. "
        f"Используя информацию, содержащуюся в пронумерованных ИСТОЧНИКАХ после слова ТЕКСТ, "
        f"ответьте на вопрос, заданный после слова ВОПРОС. "
        f"Если в тексте нет информации, необходимой для ответа, ответьте «Недостаточно информации для ответа». "
        f"Структурируйте свой ответ и отвечайте шаг за шагом. При ответе с использованием информации из текста, "
        f"используйте ссылки в скобках, содержащие номер ИСТОЧНИКА с релевантной информацией.\n"
        f"ТЕКСТ:\n{sources_text}\nВОПРОС:\n{question}"
    )

    #print(promptstring)
    endpoint = 'https://api.together.xyz/v1/chat/completions'
    res = requests.post(endpoint, json={
    "model": "mistralai/Mixtral-8x7B-Instruct-v0.1",
    "max_tokens": 2048,
    "prompt": f"[INST] {promptstring}  [/INST]",
    "temperature": 0.4,
    "top_p": 0.7,
    "top_k": 5,
    "repetition_penalty": 1,
    "stop": [
        "[/INST]",
        "</s>"
    ],
    "repetitive_penalty": 1,
    "update_at": "2024-02-25T16:35:32.555Z"
}, headers={
    "Authorization": "Bearer fba55128c5cf945c1c3e8349d5e86b2d284015f2faf0eab3c0cd46ab4dfef179",
})
    print(dict(json.loads(res.content))['usage']['total_tokens'])
    return dict(json.loads(res.content))['choices'][0]['message']['content'],metadatas,rets

# %%
def generate_mixtral_comment(question, answer, chunks, model, index, embeddings):
    rets = get_relevant_documents(question, chunks, model, index, embeddings)
    metadatas = [list(item.metadata.keys())[0] for item in rets]
    
    # Improved string formatting
    sources_text = ' \n\n '.join([f'ИСТОЧНИК {i+1}: {ret.page_content}' for i, ret in enumerate(rets)])
    
    promptstring = (
        f"Вы программист, который точно отвечает на вопросы пользователей на темы, связанные с программированием. "
        f"Используя информацию, содержащуюся в пронумерованных ИСТОЧНИКАХ после слова ТЕКСТ, "
        f"оцените правильность высказывания, приведенного после слова ОТВЕТ, как ответ на вопрос, заданный после слова ВОПРОС. "
        f"Если в тексте нет информации, необходимой для ответа, ответьте «0*». " #Недостаточно информации для ответа
        f"Если высказывание после слова ОТВЕТ правильное, ответьте «1*». Если высказывание после слова ОТВЕТ неправильное, ответьте «0*».\n "
        f"дополнительно используйте ссылки в скобках, содержащие номер ИСТОЧНИКА с релевантной информацией.\n"
        f"ТЕКСТ:\n{sources_text}\nВОПРОС:\n{question}\nОТВЕТ:{answer}"
    )

    #print(promptstring)
    endpoint = 'https://api.together.xyz/v1/chat/completions'
    res = requests.post(endpoint, json={
    "model": "mistralai/Mixtral-8x7B-Instruct-v0.1",
    "max_tokens": 2048,
    "prompt": f"[INST] {promptstring}  [/INST]",
    "temperature": 0.4,
    "top_p": 0.7,
    "top_k": 5,
    "repetition_penalty": 1,
    "stop": [
        "[/INST]",
        "</s>"
    ],
    "repetitive_penalty": 1,
    "update_at": "2024-02-25T16:35:32.555Z"
}, headers={
    "Authorization": "Bearer fba55128c5cf945c1c3e8349d5e86b2d284015f2faf0eab3c0cd46ab4dfef179",
})
    print(dict(json.loads(res.content))['usage']['total_tokens'])
    return dict(json.loads(res.content))['choices'][0]['message']['content'],metadatas,rets

# %%
#prompt = ''
def respond_question(prompt):
    if prompt:
        
        # Check which model is selected and call the corresponding function
        chunks, model, index, embeddings = load_faiss_index()  
        response, metadatas, rets = generate_mixtral_comment(question, answer, chunks, model, index, embeddings)#generate_mixtral_response(prompt, chunks, model, index, embeddings)
            # Process and display the response
        excerpts = '\n\n'.join([f"ИСТОЧНИК {i + 1}, {list(ret.metadata.keys())[0]}: {ret.page_content}" for i, ret in enumerate(rets)]) if rets else ""
        bibliography = '\n\n'.join([f"{i + 1}. {meta}" for i, meta in enumerate(metadatas)]) if metadatas else ""
        full_response = f"{response}\n\nИСТОЧНИКИ:\n{excerpts}\n\nСПИСОК ЛИТЕРАТУРЫ:\n\n{bibliography}"
    return full_response#f"{response}#\n\nИСТОЧНИКИ:\n{excerpts}\n\nСПИСОК ЛИТЕРАТУРЫ:\n\n{bibliography}"#full_response

# %%
def qa_check(question, answer):
    question = 'на ВОПРОС: ' + question + ' был дан ОТВЕТ: ' + answer + '. Если ОТВЕТ правильный, выведи число 1. Если ОТВЕТ не правильный, выведи число 0. Давай все ответы на русском языке'
    retrieval_results = list(ensemble_retriever.get_relevant_documents(question))
    text = ' \n\n '.join([re.sub(r'\W+', ' ', ret.page_content) for ret in retrieval_results])
    metadatas = list(set([list(item.metadata.keys())[0] for item in retrieval_results]))
    #metadatas
   # print(question)
    #print(simple_question_answering(question))
    return simple_question_answering(question)

# %%
import pandas as pd
data = pd.read_csv('train_data.csv')
data.head()
# Out:
#                                             Question  \
# 0  Как называется официальный (основной) магазин ...
# 1  С чего рекомендуется начинать пункты? (укажите...
# 2                 Что такое универсальные чек-листы?
# 3                     Назовите критерии качества ПО?
# 4  Проверки в чек-листе бывают с детализацией по ...
#
#                                               Answer  Correctness  \
# 0                                  Google App Center            0
# 1  Пункты должны начинаться с числительного или ч...            0
# 2  Можно использовать для тестирования всех возмо...            0
# 3  Качественное ПО определяется наличием красивых...            0
# 4  Под этим понимается, что в чек-листе указывает...            0
#
#                   Lesson                                            Comment
# 0      process_lection_3  Если студенты отвечают Samsung Galaxy Store ил...
# 1  introduction_lesson_2                                                NaN
# 2  introduction_lesson_2                                                NaN
# 3  introduction_lesson_1   \n \t\nответ считается неверным если не упомя...
# 4  introduction_lesson_2                                                NaN

# %%
#respond_question(prompt)

for i in tqdm(range(len(data))):#len(data)
    question, answer, corr = data.iloc[i, :3]
    print(question, answer)
    reply = respond_question(question)
   # print(reply)
    tmp = reply.replace('\n','').lower()
    #print(tmp)
    start = tmp.find('ответ:')
    #print(start)
    print(tmp[start:start+30], start)
    start = tmp.find('*', start+1)
    
    end = start#tmp.find('.', start+1)
    #print('end', end)
    output = tmp[end-2:end]
    print('Правильность ответа: ', output, ' Correct answer: ', corr)
    data.loc[i, 'Model output'] = output
#clean&correct responce
data['Model output_corr'] = [1 if '1' in row else 0 for row in data['Model output']]
# Out:
#   0%|          | 0/225 [00:00<?, ?it/s]
# Как называется официальный (основной) магазин приложений для устройств Android? Google App Center
# 452
# ответ: 0* (google play store,  1
# Правильность ответа:   0  Correct answer:  0
# С чего рекомендуется начинать пункты? (укажите части речи) Пункты должны начинаться с числительного или частицы.
# 526
# ответ: 0* (согласно источникам 1
# Правильность ответа:   0  Correct answer:  0
# Что такое универсальные чек-листы? Можно использовать для тестирования всех возможных ПО.
# 560
# ответ: 0* (примечание: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Назовите критерии качества ПО? Качественное ПО определяется наличием красивых кнопок и анимации при клике.
# 561
# ответ: 0* пояснение: в тексте  1
# Правильность ответа:   0  Correct answer:  0
# Проверки в чек-листе бывают с детализацией по версиям. Что имеется ввиду под этим? Под этим понимается, что в чек-листе указывается, какие проверки должны быть выполнены до выпуска новой версии программного обеспечения.
# 712
# ответ: 1* (источник 1) - здесь 1
# Правильность ответа:   1  Correct answer:  0
# Зачем нужны сервисы дистрибуции мобильных приложений? Для удобства распространения тестовых билдов.
# 647
#  -1
# Правильность ответа:   1  Correct answer:  1
# Что такое тестовые данные? Тестовые данные - это информация, которую тестировщики создают на ходу, не обращаясь к требованиям.
# 2485
#  -1
# Правильность ответа:   1  Correct answer:  0
# Назовите цели тестирования. Цели тестирования — это те задачи, которыми вы будете заниматься практически на любом проекте:
# 1) Оценка соответствия стандартам компании рабочих продуктов: требований, пользовательских историй, проектирования и кода.
# 2) Проверка выполнения требований.
# 3) Поиск и предотвращение дефектов.
# 535
#  -1
# Правильность ответа:  pd  Correct answer:  1
# Что такое окружение? Техника, которая находится у тестировщика.
# 2491
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое связнный чек лист? Связанный чек-лист - это просто список задач, который составлен хаотично, без какой-либо организации или структуры.
# 559
# ответ: 0* (связанный чек-лист  1
# Правильность ответа:   0  Correct answer:  0
# Возможно ли исчерпывающее (полное тестирование)? Скорее нет
# 433
#  -1
# Правильность ответа:  pd  Correct answer:  1
# Что такое нативные мобильные приложения? Нативные мобильные приложения - это приложения, которые создаются из натуральных ингредиентов, таких как фрукты и овощи.
# 1013
# ответ: 0* (нативные мобильные  1
# Правильность ответа:   0  Correct answer:  0
# Зачем мы используем App Store Connect? Чтобы тестировать мобильные приложения
# 487
# ответ: 0* (нет информации о це 1
# Правильность ответа:   0  Correct answer:  0
# Что такое раннее тестирование? Раннее тестирование - это когда вы начинаете тестировать программу только за неделю до её запуска.
# 542
# ответ: 0* (источник 1 и источн 1
# Правильность ответа:   0  Correct answer:  0
# Что такое тестирование програмного обеспечения? Дайте полное определение. Это просто набор тестовых случаев, которые нужно выполнить перед тем, как выпустить программу.
# 713
# ответ: 0* (источник 1 не содер 1
# Правильность ответа:   0  Correct answer:  0
# Что такое гибридные мобильные приложения? Гибридные приложения — это мобильные приложения, представляющие собой сочетание между нативными и веб-приложениями.
# 785
# ответ: 1* (источник 1 и источн 1
# Правильность ответа:   1  Correct answer:  1
# На основе какого документа составляют чек-листы? Они составляются на основе историй успеха из жизни тестировщика, чтобы вдохновиться перед началом работы.
# 557
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Возможно ли исчерпывающее (полное тестирование)? К этому нужно стремиться
# 451
# ответ: 0* (источник 2) источни 1
# Правильность ответа:   0  Correct answer:  0
# Что такое чек-лист в тестировании? Это просто список событий, которые должны произойти во время тестирования, но без какой-либо организации или систематизации.
# 565
#  -1
# Правильность ответа:   1  Correct answer:  0
# Перечислите типичные виды, которые применяются в мобильном тестировании? Типичные виды, которые применяются в мобильном тестировании:
# 1) Функциональное тестирование
# 2) Тестирование совместимости
# 3) Тестирование производительности
# 4) Стресс-тесты
# 5) Тестирование безопасности
# 6) Тестирование юзабилити
# 7) Тестирование локализации и глобализации
# 8) Тестирование установки и обновления
# 670
# ответ: 1* примечание: в источн 1
# Правильность ответа:   1  Correct answer:  1
# Приведите 2 и более примеров SDK из лекции Adobe Photoshop (для редактирования фотографий и создания графики)
# 589
#  -1
# Правильность ответа:   1  Correct answer:  0
# На основе какого документа составляют чек-листы? На основе готового приложения
# 491
# ответ: 0* (источник 1: програм 1
# Правильность ответа:   0  Correct answer:  0
# Зачем мы тестируем мобильные приложение по гайдлайнам/требованиям площадок? Чтобы приложения прошли проверки в мобильных сторах, мы должны выполнять требования площадок
# 491
#  -1
# Правильность ответа:   1  Correct answer:  1
# Подходят ли эмулятор и симулятор для отладки приложения? Симуляторы лучше подходят для отладки, чем эмуляторы.
# 1091
# ответ: 0* обоснование: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Опишите последовательность дейсвий при составлении чек-листа. Первым делом рассмотреть стандартные шаблоны чек-листов для аналогичных проектов, а затем подготовить колонки, учитывая специфику тестируемого продукта.
# 622
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# С чего рекомендуется начинать пункты? (укажите части речи) При составлении пунктов важно придерживаться унифицированных форм: начинать их с существительного («Проверка», «Добавление», «Отправка») или неопределённой формы глагола («Проверить», «Добавить», «Отправить»). Так пункты будут понятными и однозначными.
#
# 667
#  -1
# Правильность ответа:   1  Correct answer:  1
# Зачем мы тестируем мобильные приложение по гайдлайнам/требованиям площадок? Мы тестируем мобильные приложения по гайдлайнам, чтобы добавить больше странностей и неожиданных поворотов в наши продукты.
# 500
# ответ: 0* (не соответствует ин 1
# Правильность ответа:   0  Correct answer:  0
# Что такое эмулятор? Эмулятор - это программа, создающая эмоциональную связь между пользователем и искусственным интеллектом, чтобы сделать его более человечным.
# 563
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Что такое чек-лист в тестировании? Чек-лист - это специальный вид карандаша, который используется тестировщиками для отметок на бумаге.
# 573
# ответ: 0* (чек-лист - это спис 1
# Правильность ответа:   0  Correct answer:  0
# Что такое ферма устройств? Ферма устройств - это место, где содержатся и разводятся физические устройства, такие как компьютеры и смартфоны.
# 567
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# К правилам составления чек-листа относится "один пункт-одна операция". Верно ли это утверждение? Не знаю
# 567
# ответ: 1* пояснение: в источни 1
# Правильность ответа:   1  Correct answer:  0
# Проверки в чек-листе бывают с детализацией по версиям. Что имеется ввиду под этим? В чек-листе хранится история прохождения для разных версий ПО. Это полезно для отслеживания: в одних местах чаще возникают ошибки, а в других всё относительно стабильно.
# 559
# ответ: 1* (источник: источник  1
# Правильность ответа:   1  Correct answer:  1
# Какую информацию хранит раздел App Bundle Explorer в Google Play Console? Список самых популярных книг на Google Play
# 546
# ответ: 0* (в разделе app bundl 1
# Правильность ответа:   0  Correct answer:  0
# Подходят ли эмулятор и симулятор для отладки приложения? Да, оба подходят одинаково хорошо для отладки приложения.
# 614
# ответ: 0* обоснование: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Что такое чек-лист в тестировании? Чек-лист - это магический документ, который автоматически обнаруживает все ошибки в программе.
# 579
# ответ: 0* (примечание: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Как мы определяем доли рынка для разных мобильных платформ ? Проводим опросы среди наших сотрудников, чтобы узнать, какие у них мобильные устройства, и делаем выводы о долях рынка.
# 666
# ответ: 0*. 2021-02-26 14:45:45 581
# Правильность ответа:   0  Correct answer:  0
# Подходят ли эмулятор и симулятор для отладки приложения? Оба подходят для отладки.
# 2501
# ответ: 1* обоснование: в источ 1
# Правильность ответа:   1  Correct answer:  0
# Опишите последовательность дейсвий при составлении чек-листа. Начать с того, чтобы провести обзор кода или документации проекта, а затем приступить к определению структуры и содержания чек-листа.
# 686
# ответ: 0*.пояснение: в тексте  1
# Правильность ответа:   0  Correct answer:  0
# Что такое матрица совместимости устройств? Матрица совместимости устройств - это список случайно выбранных устройств, на которых проводится тестирование без какой-либо системы или структуры.
# 2500
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что означает статус blocked? Дайте развернутый ответ. Это когда тестировщик попал в блокировку из-за проблем с доступом к ресурсам.
# 585
# ответ: 0* примечание: в источн 1
# Правильность ответа:   0  Correct answer:  0
# Что такое гибридные мобильные приложения? Гибридные мобильные приложения - это приложения, которые могут менять свои функции в зависимости от того, кто их использует.
# 639
# ответ: 1*  (источник 1, источн 38
# Правильность ответа:   1  Correct answer:  0
# Что такое связнный чек лист? Это чек-лист, где каждая проверка зависит от всех предыдущих, и если хоть одна проверка не пройдена, весь чек-лист считается не пройденным.
# 602
# ответ: 0* (связанный чек-лист  1
# Правильность ответа:   0  Correct answer:  0
# Что такое матрица совместимости устройств? Это документ, который содержит информацию только о совместимости устройств с определенными программами, но не о том, как проводить тестирование.
# 583
#  -1
# Правильность ответа:   1  Correct answer:  0
# Какие существуют предпосылки к тому, что там следует внедрить автоматизацию? Перечислите 4 тезиса. Существует несколько предпосылок к тому, когда нам следует внедрять автоматизацию тестирования.
# 1) Цикл тестирования приложения становится всё больше с каждым разом
# 2) Увеличение внутреннего парка мобильных устройств
# 3) Большое количество регрессионных тестов
# 4) Поддержка большого числа версий операционных систем
#
# 617
# ответ: 1* (источник 2 и 3 подт 1
# Правильность ответа:   1  Correct answer:  1
# Как называется официальный магазин приложений для устройств Apple? Google Play Store
# 422
#  -1
# Правильность ответа:   1  Correct answer:  0
# Как называется официальный (основной) магазин приложений для устройств Android? Google Play Store
# 427
#  -1
# Правильность ответа:   1  Correct answer:  1
# Перечислите типичные виды, которые применяются в мобильном тестировании? Исследование влияния цветовой гаммы на эмоциональное состояние пользователя.
# 520
# ответ: 0* (нет информации о ти 1
# Правильность ответа:   0  Correct answer:  0
# Какую информацию хранит раздел App Bundle Explorer в Google Play Console? Историю покупок в Google Play Store
# 2521
# ответ: 0* (в разделе app bundl 1
# Правильность ответа:   0  Correct answer:  0
# Что такое эмулятор? Эмулятор - это человек, который воспроизводит действия и поведение реального пользователя для тестирования приложений.
# 497
#  -1
# Правильность ответа:   1  Correct answer:  0
# Какие этапы включает в себя тестирование? Тестирование включает в себя следующие этапы: установка программы и удаление её, потому что она не работает.
# 2518
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое Xcode? Xcode — это IDE (Integrated Development Environment, «интегрированная среда разработки»), созданная для разработки iOS-приложений.
# 556
# ответ: 1* (источник 1, 3) в от 1
# Правильность ответа:   1  Correct answer:  1
# Что такое TestFlight? Место для публикации мобильного приложения
# 416
#  -1
# Правильность ответа:   1  Correct answer:  0
# С чего рекомендуется начинать пункты? (укажите части речи) Пункты всегда начинаются с предлога или местоимения.
# 530
# ответ: 0* (источник 1 и источн 1
# Правильность ответа:   0  Correct answer:  0
# Перечислите типичные виды, которые применяются в мобильном тестировании? Определение скорости, с которой мобильное устройство может вращаться на 360 градусов.
# 608
# ответ: 0* (нет информации о ти 1
# Правильность ответа:   0  Correct answer:  0
# Что такое Xcode? Это полный набор программного обеспечения, и с его помощью разработчики могут выполнять множество задач, таких как проектирование пользовательского интерфейса, разработка кода для приложений, компиляция и тестирование кода, а также проверка наличия ошибок в коде.
# 2526
# ответ: 1* примечание: в тексте 1
# Правильность ответа:   1  Correct answer:  1
# Зачем нужны сервисы дистрибуции мобильных приложений? Они используются для того, чтобы улучшить цветовую гамму приложений и сделать их более привлекательными для пользователей.
# 563
# ответ: 0* (нет информации о се 1
# Правильность ответа:   0  Correct answer:  0
# Что такое тестовые данные? Это просто данные, которые тестировщики придумывают сами, без каких-либо стандартов или требований.
# 447
#  -1
# Правильность ответа:   1  Correct answer:  0
# Какие бывают статусы в чек листе и что они означают? 1) passed — успешно пройден
# 2) failed — кейс не прошел проверку
# 3) skipped — пропуск проверки
# 4 blocked — проверка заблокирована
# 5) untested — кейс еще не брали в работу
# 550
# ответ: 1* (источник 1: 5. в ка 1
# Правильность ответа:   1  Correct answer:  1
# Какие этапы включает в себя тестирование? Этапы тестирования: собрать команду из любителей видеоигр, дать им пять минут, чтобы понять, что программа не игра, и затем переключиться на другую задачу.
# 2536
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое тестирование програмного обеспечения? Дайте полное определение. Тестирование программного обеспечения - это бесполезная трата времени и ресурсов.
# 537
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое гибридные мобильные приложения? Это приложения для конкретной платформы. Разрабатываются с помощью SDK, инструментов разработки, датчиков и функций конкретных платформ.
#
# 535
# ответ: 0* (неправильное высказ 1
# Правильность ответа:   0  Correct answer:  0
# Что такое крешлоги? Крэшлоги — это данные о том, что происходило с приложением в момент сбоя, а также данные о разделе приложения, в котором произошёл сбой.
# 1054
# ответ:крэшлоги — это данные о  1302
# Правильность ответа:   1  Correct answer:  1
# С чего рекомендуется начинать пункты? (укажите части речи) С существительного
# 465
# ответ: 1* источники:источник 1 1
# Правильность ответа:   1  Correct answer:  0
# Что такое эмулятор? Эмулятор - это устройство, которое используется для эмуляции погодных условий внутри помещения.
# 518
# ответ: 0* (примечание: эмулято 1
# Правильность ответа:   0  Correct answer:  0
# Как называется официальный (основной) магазин приложений для устройств Android? Android Market
# 426
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое ферма устройств? Это место, где производят выращивание овощей и фруктов с использованием специальных агротехнологий.
# 514
# ответ: 0* (источник не содержи 1
# Правильность ответа:   0  Correct answer:  0
# На чем может проводиться тестирование мобильных приложений? Тестирование мобильных приложений может проводиться на компьютерах с установленными эмуляторами и симуляторами.
# 663
# ответ: 0* (примечание: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Назовите цели тестирования. Цели тестирования:
# 1) определить, насколько ПО соответствует заявленным требованиям;
# 2) выявить дефекты, то есть отклонения ПО от требований.
#
# 929
# ответ: 1* (источник 3) [inst]  1
# Правильность ответа:   1  Correct answer:  1
# Что такое универсальные чек-листы? Для универсального чек-листа составляется абстрактный список проверок.
# 2506
# ответ: 1* (источник 1, источни 1
# Правильность ответа:   1  Correct answer:  1
# Как мы определяем доли рынка для разных мобильных платформ ? Определять доли рынка для разных мобильных платформ можно по количеству проданных на рынке ноутбуков
# 875
# ответ:определять доли рынка дл 1286
# Правильность ответа:  pd  Correct answer:  0
# Подходят ли эмулятор и симулятор для отладки приложения? Эмулятор больше подходит для отладки. Симулятор в меньшей степени подходит для отладки.
# 746
# ответ: 1* обоснование: в источ 1
# Правильность ответа:   1  Correct answer:  1
# На основе какого документа составляют чек-листы? Чек-листы создаются на основе прошлых ошибок, чтобы каждый раз повторять одни и те же тесты.
# 547
# ответ: 0* (источник 1: програм 1
# Правильность ответа:   0  Correct answer:  0
# На основе какого документа составляют чек-листы? На основе здравого смысла
# 464
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое гибридные мобильные приложения? Это приложения, которые предназначены для использования только в экстремальных условиях, таких как горные вершины или пустынные районы.
# 957
# ответ: 0* (нет информации о ги 1
# Правильность ответа:   0  Correct answer:  0
# Как называется официальный (основной) магазин приложений для устройств Android? Play App Store
# 446
# ответ: 0* (google play store)  1
# Правильность ответа:   0  Correct answer:  0
# Что такое симулятор? Симулятор - это специализированная камера, используемая для создания трехмерных моделей объектов.
# 2491
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое Xcode? Это один из самых популярных инструментов для создания приложений.
# 2471
# ответ: 1* примечание: в тексте 1
# Правильность ответа:   1  Correct answer:  1
# На основе какого документа составляют чек-листы? Их составляют на основе рецептов бабушки, потому что так было всегда, и это работает.
# 508
# ответ: 0* (не соответствует ин 1
# Правильность ответа:   0  Correct answer:  0
# На чем проводить тестирование важнее всего? (реальных девайсах, эмуляторах, симуляторах или моб фермах) эмуляторах
# 570
# ответ: 0* пояснение: в источни 1
# Правильность ответа:   0  Correct answer:  0
# Что такое архитектура набора команд? Код приложения
# 445
#  -1
# Правильность ответа:  pd  Correct answer:  0
# На чем проводить тестирование важнее всего? (реальных девайсах, эмуляторах, симуляторах или моб фермах) симуляторах
# 511
#  -1
# Правильность ответа:   1  Correct answer:  0
# Возможно ли исчерпывающее (полное тестирование)? Возможно
# 623
#  -1
# Правильность ответа:   1  Correct answer:  0
# Зачем мы интегрируем SDK в наши программы? Напишите хотя бы одну причину. Во-первых, это может быть обязательным требованием для работы с платформой. Например, наша команда решила, что мы будем собирать статистику по нашему проекту, используя Adjust. Для того чтобы подключить этот сервис, нам обязательно нужно интегрировать их SDK. Только после этого платформа может понять, какие данные и по каким приложениям собирать.
# Во-вторых, это облегчает и ускоряет процесс разработки и тестирования. Представим, что у нас в приложении есть встроенные покупки. И вместо того, чтобы самостоятельно разрабатывать систему, которая будет обрабатывать и принимать платежи (а это довольно объёмная и сложная задача), мы интегрируем SDK платформы, на которой выпускаем приложение (пусть будет Google Play и App Store). Таким образом, мы будем использовать инструмент, который создавался сторонней компанией, уже протестирован и, что немаловажно, — выпускает обновления.
# В-третьих, у крупных платформ есть саппорт. К нему разработчики могут обратиться, когда возникают какие-то сложности с интеграцией, или если необходимые функции не работают как надо.
# 832
# ответ: 1* (источник 2) или 1*  1
# Правильность ответа:   1  Correct answer:  1
# Что такое нативные мобильные приложения? Нативные мобильные приложения - это приложения, которые могут быть установлены только на одно устройство и не могут быть перенесены на другие.
# 574
# ответ: 0* примечание: в источн 1
# Правильность ответа:   0  Correct answer:  0
# Что подразумевает под собой аббревиатура QA (Quality Assurance) ? Это просто аббревиатура, которая означает "Квалифицированный Анализ" и ничего не связано с тестированием.
# 546
# ответ: 0* (qa (quality assuran 1
# Правильность ответа:   0  Correct answer:  0
# На основе какого документа составляют чек-листы? Чек-листы составляются на основе погоды во время тестирования, чтобы узнать, можно ли в этот день проводить тестирование.
# 521
# ответ: 0* (нет информации о до 1
# Правильность ответа:   0  Correct answer:  0
# Что такое тестовые данные? По сути, полигон для испытаний: например, сервер, мобильный телефон и так далее. Настраивается в соответствии с требованиями тестируемого приложения.
#
# 516
# ответ: 0* (примечание: ответ н 1
# Правильность ответа:   0  Correct answer:  0
# Что такое связнный чек лист? Это чек-лист, где последовательность проверок не имеет значения, и можно выполнять их в любом порядке.
# 570
# ответ: 1* (связанный чек-лист  1
# Правильность ответа:   1  Correct answer:  0
# Что такое окружение? Это, когда вы окружены разными программами на своем компьютере.
# 534
# ответ: 0* обоснование: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Что такое гибридные мобильные приложения? Приложения которые разрабатываются тестировщиками и разработчиками вместе.
# 535
# ответ: 0* (в тексте не содержи 1
# Правильность ответа:   0  Correct answer:  0
# Как мы определяем доли рынка для разных мобильных платформ ? Прикидываем какими телефонами пользуются люди.
# 2466
# ответ: 1* пояснение: в тексте  1
# Правильность ответа:   1  Correct answer:  0
# К правилам составления чек-листа относится "один пункт-одна операция". Верно ли это утверждение? Нет
# 564
# ответ: 0* (в источниках 1 и 2  1
# Правильность ответа:   0  Correct answer:  0
# Что такое тестирование програмного обеспечения? Дайте полное определение. Это проверка наличия ошибок в приложении.
# 2515
#  -1
# Правильность ответа:   1  Correct answer:  0
# Возможно ли исчерпывающее (полное тестирование)? Да
# 670
# ответ: 0* (источник 1, источни 57
# Правильность ответа:   0  Correct answer:  0
# Что такое тестовые данные? Это программы, которые быстро создают тестовые данные. Их целесообразно использовать в случаях, когда:
# 2482
# ответ: 0* [inst] примечание: в 1
# Правильность ответа:   0  Correct answer:  0
# Что означает статус blocked? Дайте развернутый ответ. blocked — проверка заблокирована поломанным функционалом, от которого прямо или косвенно зависит тестируемый.
# 648
# ответ: 1* примечание: в ответе 1
# Правильность ответа:   1  Correct answer:  1
# Возможно ли исчерпывающее (полное тестирование)? Полное тестирование с использованием всех комбинаций вводов и предусловий физически невыполнимо, кроме тривиальных случаев. Вместо исчерпывающего тестирования используется анализ рисков и расстановка приоритетов, чтобы точнее сфокусировать усилия по тестированию.
#
# 558
# ответ: 1* (источник 2) - полно 1
# Правильность ответа:   1  Correct answer:  1
# Что такое гибридные мобильные приложения? Гибридные мобильные приложения - это приложения, которые могут менять свою форму в зависимости от фазы луны.
# 2506
# ответ: 0* (нет информации о св 1
# Правильность ответа:   0  Correct answer:  0
# Что такое крешлоги? Крэшлоги - это новый вид игрового контента, который добавляет в игру элементы неожиданности и волнения.
# 568
# ответ: 0* примечание: крешлоги 1
# Правильность ответа:   0  Correct answer:  0
# Что означает статус blocked? Дайте развернутый ответ. Это когда проверка заблокирована из-за плохой погоды или других внешних обстоятельств.
# 602
# ответ: 0* примечание: в источн 1
# Правильность ответа:   0  Correct answer:  0
# Назовите критерии качества ПО? Критерии качества ПО: цветной интерфейс, много анимации и красивые шрифты.
# 584
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Что такое чек-лист в тестировании? Это список дел
# 706
#  -1
# Правильность ответа:   1  Correct answer:  0
# Какие существуют предпосылки к тому, что там следует внедрить автоматизацию? Перечислите 4 тезиса. Недостаток ресурсов для найма большого количества тестировщиков.
# 519
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое универсальные чек-листы? Универсальные чек-листы подходят для тестирования проектов одного типа.
#
# 486
#  -1
# Правильность ответа:   1  Correct answer:  1
# Что такое матрица совместимости устройств? Это таблица, где перечислены все возможные устройства, с которыми работает разработчик, без дополнительной информации о том, как их тестировать.
# 567
# ответ: 0* пояснение: в тексте  1
# Правильность ответа:   0  Correct answer:  0
# Назовите цели тестирования. Тестирование нужно для того, чтобы просто провести как можно больше тестов.
# 506
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что подразумевает под собой аббревиатура QA (Quality Assurance) ? QA (Quality Assurance) - это квантовая архитектура, которая используется для обеспечения качества программного обеспечения.
# 525
# ответ: 0* (qa (quality assuran 1
# Правильность ответа:   0  Correct answer:  0
# Что такое Xcode? Xcode - это приложение для просмотра видеофайлов.
# 496
# ответ: 0* (в тексте не содержи 1
# Правильность ответа:   0  Correct answer:  0
# На чем проводить тестирование важнее всего? (реальных девайсах, эмуляторах, симуляторах или моб фермах) мобильных фермах
# 536
#  -1
# Правильность ответа:   1  Correct answer:  0
# Зачем мы тестируем мобильные приложение по гайдлайнам/требованиям площадок? Это делается просто потому, что нам скучно без каких-либо правил и ограничений.
# 504
# ответ: 0* (нет информации о пр 1
# Правильность ответа:   0  Correct answer:  0
# Что такое раннее тестирование? Когда тестировщик с раннего утра начинает тестировать продукт чтобы успеть сделать больше дел.
# 584
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Что такое SDK? SDK означает "Служба дистрибуции котят", предоставляемая приютами для бездомных животных.
# 535
# ответ: 0* (нет информации о то 1
# Правильность ответа:   0  Correct answer:  0
# Что такое раннее тестирование? Раннее тестирование означает, что вы тестируете программу только после того, как пользователи начнут жаловаться на проблемы.
# 556
# ответ: 0* (раннее тестирование 1
# Правильность ответа:   0  Correct answer:  0
# Зачем нужны сервисы дистрибуции мобильных приложений? Эти сервисы позволяют распространять тестовые версии нашего приложения среди тестировщиков по беспроводной сети (OTA — Over The Air). Ими мы пользуемся, чтобы не собирать каждый раз приложение непосредственно на устройствах или не передавать сборку приложения просто файлом (это может быть неудобно и небезопасно).
# 810
# ответ: 1* примечание: в ответе 1
# Правильность ответа:   1  Correct answer:  1
# На основе какого документа составляют чек-листы? Чек-листы составляют на основе технического задания (ТЗ) — одного или нескольких документов, определяющих цель, структуру, свойства и методы проекта.
# 505
#  -1
# Правильность ответа:   1  Correct answer:  1
# Что такое окружение? Мир вокруг нас.
# 662
# ответ: 0* (примечание: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Что подразумевает под собой аббревиатура QA (Quality Assurance) ? QC (Quality Control) — контроль качества: анализ результатов тестирования и качества новых версий выпускаемого продукта.
# Задачи:
# 1) проверка готовности ПО к релизу;
# 2) проверка соответствия требований и качества проекта.
#
# 770
# ответ: 0* reasoning: qa (quali 1
# Правильность ответа:   0  Correct answer:  0
# Опишите последовательность дейсвий при составлении чек-листа. Начать с того, чтобы провести обзор кода или документации проекта, а затем приступить к определению структуры и содержания чек-листа.
# 1051
# ответ: 0* (примерно соответств 1
# Правильность ответа:   0  Correct answer:  0
# На чем может проводиться тестирование мобильных приложений? На облачных платформах, где можно создавать и запускать тестовые среды для мобильных устройств.
# 889
# ответ: на облачных платформах, 1309
# Правильность ответа:  pd  Correct answer:  0
# Зачем мы используем App Store Connect? Для создания музыкальных плейлистов
# 489
# ответ: 0* (нет информации о це 1
# Правильность ответа:   0  Correct answer:  0
# Что такое SDK? SDK — это специальная программа для шифрования данных на компьютере.
# 477
# ответ: 0* (нет информации о ши 1
# Правильность ответа:   0  Correct answer:  0
# Что такое окружение? Окружение - это просто слово для описания погоды и природы вокруг нас.
# 920
# ответ: 0* (окружение - это сре 1
# Правильность ответа:   0  Correct answer:  0
# Какие этапы включает в себя тестирование? Тестирование состоит из двух этапов: запуск программы и проверка, работает ли она правильно.
# 2514
#  -1
# Правильность ответа:   1  Correct answer:  0
# Какую информацию хранит раздел App Bundle Explorer в Google Play Console? Там можно сказать приложения Amazon
# 2520
# ответ: 0* (нет информации о ра 1
# Правильность ответа:   0  Correct answer:  0
# Что такое симулятор? Симулятор — это программное обеспечение, которое помогает вашему компьютеру запускать определённые программы, созданные для другой операционной системы.
#
# 462
#  -1
# Правильность ответа:   1  Correct answer:  1
# Назовите цели тестирования. Цели тестирования: найти ошибки/дефекты и исправить их.
# 563
# ответ: 0* пояснение: в тексте  1
# Правильность ответа:   0  Correct answer:  0
# Что такое ферма устройств? Магазин телефонов
# 493
# ответ: 0* (примерный ответ: гр 1
# Правильность ответа:   0  Correct answer:  0
# Зачем мы интегрируем SDK в наши программы? Напишите хотя бы одну причину. Для затруднения доступа к данным в нашем приложении.
# 657
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Что такое нативные мобильные приложения? Это приложения, которые работают только на мобильных устройствах, но не имеют никакого отношения к операционной системе.
# 578
# ответ: 0* примечание: нативные 1
# Правильность ответа:   0  Correct answer:  0
# Что такое тестовые данные? Тестовые данные - это случайные числа и символы, которые тестировщики вводят в программу.
# 529
# ответ: 0* (примечание: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Возможно ли исчерпывающее (полное тестирование)? Глобально нет
# 519
# ответ: 0* (источник 2) и источ 1
# Правильность ответа:   0  Correct answer:  1
# Что такое TestFlight? TestFlight - это новый вид аттракционов в тематическом парке.
# 481
# ответ: 0* (testflight — это ме 1
# Правильность ответа:   0  Correct answer:  0
# Какие этапы включает в себя тестирование? Этапы тестирования: придумать название программы, купить книгу по программированию, выпить чашечку кофе, надеяться на удачу.
# 520
# ответ: 0* (примечание: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Возможно ли исчерпывающее (полное тестирование)? Невозможно
# 441
#  -1
# Правильность ответа:   1  Correct answer:  1
# Что такое универсальные чек-листы? Универсальные чек-листы - это списки, которые составляются только для одного конкретного проекта и не могут быть использованы для других.
# 554
# ответ: 0* (источник 1, источни 1
# Правильность ответа:   0  Correct answer:  0
# Приведите 2 и более примеров SDK из лекции Google Play и App Store (для выпуска приложения, настройки покупок внутри приложения и получения статистики)
# Facebook (для использования инструментов рекламы, продвижения и статистики Facebook)
# Crashlytics (для отслеживания статистики и крэшей пользователей)
# HelpShift (для интеграции сервиса работы с техподдержкой через приложение)
#
# 2614
# ответ: 1* примечание: в ответе 1
# Правильность ответа:   1  Correct answer:  1
# Что такое архитектура набора команд? Код ОС
# 445
#  -1
# Правильность ответа:  pd  Correct answer:  0
# Как называется официальный магазин приложений для устройств Apple? App Store
# 421
#  -1
# Правильность ответа:   1  Correct answer:  1
# Проверки в чек-листе бывают с детализацией по версиям. Что имеется ввиду под этим? Это когда чек-лист делится на разные разделы для разных версий программного обеспечения.
# 2553
# ответ: 1* (источник: проверки  1
# Правильность ответа:   1  Correct answer:  0
# Зачем нужны сервисы дистрибуции мобильных приложений? Чтобы олегчить тестирование.
# 501
# ответ: 1* (сервисы дистрибуции 8
# Правильность ответа:   1  Correct answer:  0
# Что означает статус blocked? Дайте развернутый ответ. blocked — проверка заблокирована
# 2530
# ответ: 1* примечание: в ответе 1
# Правильность ответа:   1  Correct answer:  0
# Что такое чек-лист в тестировании? Чек-лист (Check List) – это список, содержащий ряд проверок во время тестирования программного продукта.
# 516
# ответ: 1* (источник 1) источни 1
# Правильность ответа:   1  Correct answer:  1
# Что такое универсальные чек-листы? Универсальные чек-листы - это списки проверок, которые подходят для всех типов проектов, независимо от их характера и специфики.
# 532
# ответ: 1* (источник 2) - униве 1
# Правильность ответа:   1  Correct answer:  0
# Зачем мы интегрируем SDK в наши программы? Напишите хотя бы одну причину. Чтобы усложнить процесс обновления приложения.
# 565
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Зачем мы тестируем мобильные приложение по гайдлайнам/требованиям площадок? Чтобы мобильные приложения становились менее функциональными и более запутанными.
# 547
# ответ: 0* (нет информации о то 1
# Правильность ответа:   0  Correct answer:  0
# Назовите цели тестирования. Тестирование нужно, чтобы занять себя, когда делать больше нечего.
# 968
# ответ: 0* (нет информации о це 1
# Правильность ответа:   0  Correct answer:  0
# Что такое тестирование програмного обеспечения? Дайте полное определение. Это проверка соответствия реального и ожидаемого поведения программы, а также степени удовлетворения потребностей пользователя.
# 2530
# ответ: 1* (источник 1) вот и п 1
# Правильность ответа:   1  Correct answer:  1
# Как называется официальный магазин приложений для устройств Apple? Apple Market
# 439
# ответ: 0* (app store) [источни 1
# Правильность ответа:   0  Correct answer:  0
# Опишите последовательность дейсвий при составлении чек-листа. Последовательность действий при составлении чек-листа:
# 1) Определить все возможные проверки.
# 2) Сгруппировать проверки в разделы.
# 3) Определить тестовые данные, если они необходимы.
# 4) Подумать, какие колонки будут в чек-листе.
# 5) Затем составляется сам чек-лист.
#
# 2578
# ответ: 1* примечание: в источн 1
# Правильность ответа:   1  Correct answer:  1
# Что такое SDK? Software Development Kit (SDK) — набор инструментов и программ, используемых разработчиками для создания приложений для определённых платформ, операционных систем, компьютерных систем или устройств.
# 2526
# ответ: 1* (источник 1, 2, 3) в 1
# Правильность ответа:   1  Correct answer:  1
# Что такое архитектура набора команд? Более простыми словами, ISA — это набор инструкций, написанных на машинном языке каждым из семейств процессоров. Они используются для создания собственной конфигурации устройства, отражающей функциональность и поведение устройства. Когда мы пользуемся разными версиями компьютеров, у каждого из устройств есть свой код, который отвечает за то, как работает устройство с определёнными характеристиками. Например, есть Наборы команд на базе архитектуры Intel, Наборы команд на базе архитектуры AMD.
#
# 724
# ответ: 1*  (архитектура набора 1
# Правильность ответа:   1  Correct answer:  1
# Что такое нативные мобильные приложения? Приложения разработанные правильно.
# 535
# ответ: 0* примечание: нативные 1
# Правильность ответа:   0  Correct answer:  0
# Проверки в чек-листе бывают с детализацией по версиям. Что имеется ввиду под этим? Это означает, что проверки в чек-листе бывают с разной степенью сложности для разных версий программного обеспечения.
# 2562
# ответ: 1* (источник 1) - в чек 1
# Правильность ответа:   1  Correct answer:  0
# Что такое Xcode? Среда разработки android приложений.
# 892
# ответ: 0* (примечание: xcode - 1
# Правильность ответа:   0  Correct answer:  0
# Что такое связнный чек лист? Все пункты чек-листа связаны между собой.
# 2535
# ответ: 1* (источник 2) #### 2. 1
# Правильность ответа:   1  Correct answer:  0
# На основе какого документа составляют чек-листы? Чек-листы составляют на основе технического задания (ТЗ)
# 484
#  -1
# Правильность ответа:   1  Correct answer:  1
# Какие бывают статусы в чек листе и что они означают? passed - это когда проверка прошла на ура, а failed - это когда она провалилась.
# 495
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что означает статус blocked? Дайте развернутый ответ. Статус blocked означает, что тестировщик заблокировал проверку, потому что ему лень её проводить.
# 592
# ответ: 0* (неправильный ответ) 1
# Правильность ответа:   0  Correct answer:  0
# Проверки в чек-листе бывают с детализацией по версиям. Что имеется ввиду под этим? Это когда в чек-листе указывается, какие проверки были выполнены на разных этапах разработки ПО.
# 1018
# ответ: 1* (источник 1) [inst]  1
# Правильность ответа:   1  Correct answer:  0
# Зачем мы интегрируем SDK в наши программы? Напишите хотя бы одну причину. Для создания дополнительной сложности в разработке.
# 611
# ответ: 0* пояснение: в тексте  1
# Правильность ответа:   0  Correct answer:  0
# Что такое чек-лист в тестировании? Чек-лист - это список покупок, который тестировщики используют перед тем, как приступить к тестированию.
# 536
#  -1
# Правильность ответа:   1  Correct answer:  0
# Возможно ли исчерпывающее (полное тестирование)? Выполнимо
# 433
#  -1
# Правильность ответа:  pd  Correct answer:  0
# Что такое связнный чек лист? Связанный чек-лист - это список проверок, где каждая проверка зависит только от предыдущей и никак не связана с последующими.
# 608
# ответ: 0* (связанный чек-лист  1
# Правильность ответа:   0  Correct answer:  0
# Зачем мы используем App Store Connect? Чтобы посмотреть последние новости о мобильных приложениях
# 491
# ответ: 0* (нет информации о це 1
# Правильность ответа:   0  Correct answer:  0
# Что такое связнный чек лист? В связанном чек-листе (англ. strongly sequential checklist) последовательность влияет на результат. Ключевой этап работы над созданием связанного чек-листа — корректное размещение информации.
# 572
# ответ: 0* (связанный чек-лист  1
# Правильность ответа:   0  Correct answer:  1
# Что такое нативные мобильные приложения? Нативные приложения — это приложения для конкретной платформы. Разрабатываются с помощью SDK, инструментов разработки, датчиков и функций конкретных платформ.
# 975
# ответ: 1* (источник 1 и источн 1
# Правильность ответа:   1  Correct answer:  1
# Назовите цели тестирования. Цель тестирования заключается в том, чтобы показать, что разработчики сделали что-то неправильно.
# 620
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Что такое гибридные мобильные приложения? Это приложения, которые создаются путем скрещивания различных животных видов.
# 2489
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое раннее тестирование? Тестирование должно начинаться как можно раньше в жизненном цикле разработки программного обеспечения, и его усилия должны концентрироваться на конкретных целях. Такой подход поможет раньше найти дефекты.
# 521
#  -1
# Правильность ответа:   1  Correct answer:  1
# На чем может проводиться тестирование мобильных приложений? На мобильных устройствах, таких как смартфоны и планшеты, для проверки реального поведения приложения.
# 557
# ответ: 1* примечание: в ответе 1
# Правильность ответа:   1  Correct answer:  0
# Подходят ли эмулятор и симулятор для отладки приложения? Эмуляторы и симуляторы применяются только для отладки аппаратного обеспечения, но не программного.
# 2519
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое эмулятор? Эмулятор - это специальный вид мебели, который используется для эмуляции различных поз и движений человеческого тела.
# 648
#  -1
# Правильность ответа:   0  Correct answer:  0
# Что такое ферма устройств? Это устройство, которое используется для эмуляции работы фермерского хозяйства в виртуальной среде.
# 548
#  -1
# Правильность ответа:   1  Correct answer:  0
# Назовите критерии качества ПО? Критерии качества ПО: количество встроенных игр, наличие мемов и способность предсказывать погоду.
# 577
# ответ: 0* описание: в ответе п 1
# Правильность ответа:   0  Correct answer:  0
# Какие бывают статусы в чек листе и что они означают? Статусы в чек-листе: весёлый, сердитый, смущённый, уставший, радостный.
# 534
# ответ: 0* (примечание: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Что такое крешлоги? Это журналы путешествий людей, которые случайно попадают в приложение и оставляют там свои записи.
# 535
# ответ: 0* (нет информации о кр 1
# Правильность ответа:   0  Correct answer:  0
# Что такое тестовые данные? Тестовые данные - это информация, которую разработчики используют для того, чтобы проверить, работает ли программа.
# 570
# ответ: 1*  (источник 1, источн 54
# Правильность ответа:   1  Correct answer:  0
# На основе какого документа составляют чек-листы? Чек-листы создаются на основе гороскопа, чтобы узнать, какие тесты проводить в текущий день.
# 2524
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое универсальные чек-листы? Универсальные чек-листы - это списки, которые проверяют только графические элементы, игнорируя другие аспекты проекта.
# 555
# ответ: 0* (источник 1, источни 1
# Правильность ответа:   0  Correct answer:  0
# Что такое окружение? Окружение - это название для группы людей, которые работают над одним проектом.
# 481
#  -1
# Правильность ответа:   0  Correct answer:  0
# Что подразумевает под собой аббревиатура QA (Quality Assurance) ? Это просто сокращение для "Quick Assessment", что означает быструю оценку программы без тщательного тестирования.
# 1036
# ответ: 0* (см. источник 1: qa  1
# Правильность ответа:   0  Correct answer:  0
# Как мы определяем доли рынка для разных мобильных платформ ? Мы определяем доли рынка, подсчитывая количество пользователей с каждой мобильной платформой, которые мы встречаем на улице.
# 2490
# ответ: 0* пояснение: в тексте  1
# Правильность ответа:   0  Correct answer:  0
# Что такое SDK? SDK это общепринятое сокращение от "Система достижений и достижений", используемая в игровой индустрии для создания игровых достижений и системы наград.
# 550
# ответ: 0* (нет информации о то 1
# Правильность ответа:   0  Correct answer:  0
# Что такое SDK? SDK это служба доставки кофе, предоставляемая компаниями для своих сотрудников.
# 478
# ответ: 0* (нет информации о ко 1
# Правильность ответа:   0  Correct answer:  0
# Какие существуют предпосылки к тому, что там следует внедрить автоматизацию? Перечислите 4 тезиса. Тестов очень много
# 2524
#  -1
# Правильность ответа:   1  Correct answer:  0
# Приведите 2 и более примеров SDK из лекции Google Maps (для навигации и поиска мест)
# 511
#  -1
# Правильность ответа:   1  Correct answer:  0
# Перечислите типичные виды, которые применяются в мобильном тестировании? Тестирование способности мобильного устройства служить в качестве тостера для подогрева бутербродов.
# 602
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Зачем нужны сервисы дистрибуции мобильных приложений? Сервисы дистрибуции мобильных приложений не нужны, так как можно просто выложить приложение на свой личный сайт и предложить его пользователям скачать.
# 645
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Как называется официальный магазин приложений для устройств Apple? Store of Apps
# 437
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое архитектура набора команд? Это технология, используемая для защиты информации в компьютерных системах путем шифрования команд и данных.
# 525
# ответ: 0* (примечание: архитек 1
# Правильность ответа:   0  Correct answer:  0
# Какими hard skills должен обалдать тестировщик? Хороший тестировщик должен обладать навыками вязания, готовки суши и знать, как играть в боулинг.
# 591
# ответ: 0* обоснование: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Какими hard skills должен обалдать тестировщик? Тестировщик должен быть хорошим поваром, знать астрономию и быть профессиональным игроком в баскетбол.
# 564
# ответ: 0* обоснование: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Что подразумевает под собой аббревиатура QA (Quality Assurance) ? QA (Quality Assurance) - это квесты и приключения, которые разработчики проходят, чтобы убедиться, что их продукт хорош.
# 563
# ответ: 0* примечание: qa (qual 1
# Правильность ответа:   0  Correct answer:  0
# Зачем мы тестируем мобильные приложение по гайдлайнам/требованиям площадок? Чтобы не составлять чек-листы самим
# 2497
# ответ: 1* [inst] вот почему: в 1
# Правильность ответа:   1  Correct answer:  0
# К правилам составления чек-листа относится "один пункт-одна операция". Верно ли это утверждение? Одно действие - две операции
# 478
#  -1
# Правильность ответа:   1  Correct answer:  0
# Как называется официальный магазин приложений для устройств Apple? App Center
# 419
#  -1
# Правильность ответа:  pd  Correct answer:  0
# Что такое гибридные мобильные приложения? Они используют встроенную оболочку приложения, которая содержит веб-представление для запуска веб-приложения внутри приложения для конкретной платформы.
# 555
# ответ: 1* примечание: в тексте 1
# Правильность ответа:   1  Correct answer:  1
# Что такое симулятор? Симулятор - это человек, который имитирует поведение реального пользователя при тестировании программного обеспечения.
# 527
# ответ: 0* примечание: симулято 1
# Правильность ответа:   0  Correct answer:  0
# Какие существуют предпосылки к тому, что там следует внедрить автоматизацию? Перечислите 4 тезиса. Попытка избежать ручного труда в любой ситуации, даже если автоматизация неэффективна или невозможна.
# 624
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Какие этапы включает в себя тестирование? Подготовка, тестирование и предоставление выводов.
# 693
# ответ: 1* (источник 1, источни 56
# Правильность ответа:   1  Correct answer:  0
# Какую информацию хранит раздел App Bundle Explorer в Google Play Console? Информация об играх, способах монетизации приложения.
# 559
# ответ: 0* (в разделе app bundl 1
# Правильность ответа:   0  Correct answer:  0
# Что такое TestFlight? TestFlight — это место, где мы можем управлять всем, что связано с процессом тестирования приложения, а также протестировать своё приложение перед выходом на рынок.
# 906
# ответ: 1* (источник 1) - соотв 1
# Правильность ответа:   1  Correct answer:  1
# Что такое ферма устройств? Ферма устройств — это группа, состоящая из множества устройств (телефонов, компьютеров или любого другого оборудования), арендованных или находящихся в собственности.
# 671
#  -1
# Правильность ответа:   1  Correct answer:  1
# Что подразумевает под собой аббревиатура QA (Quality Assurance) ? Тестирование — один из аспектов обеспечения качества.
# Задачи:
# проверка технических характеристик и требований к ПО;
# оценка рисков;
# планирование задач для улучшения качества продукции;
# подготовка документации, тестового окружения и данных;
# тестирование;
# анализ результатов тестирования, а также составление отчётов и других документов.
# 842
# ответ: 1* (источник 1: qa (qua 1
# Правильность ответа:   1  Correct answer:  1
# Что такое окружение? Окружение - это просто название для рабочего стола вашего компьютера.
# 561
# ответ: 0* обоснование: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Что такое гибридные мобильные приложения? Гибридные приложения - это приложения, которые могут работать как на мобильных устройствах, так и на настольных компьютерах одновременно.
# 713
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Возможно ли исчерпывающее (полное тестирование)? Может быть выполнимо только в очень маленьких проектах.
# 594
# ответ: 0* пояснение: в тексте  1
# Правильность ответа:   0  Correct answer:  1
# Что такое тестирование програмного обеспечения? Дайте полное определение. Это когда ты думаешь, что программа работает, но на самом деле она просто маскирует свои проблемы.
# 588
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Какими hard skills должен обалдать тестировщик? Ему нужно знать, как пользоваться кухонными приборами, разбираться в моде и уметь кататься на велосипеде.
# 492
# ответ: 0* (нет информации о ha 1
# Правильность ответа:   0  Correct answer:  0
# Что такое раннее тестирование? Раннее тестирование - это просто проверка, что программа запускается, а за баги позаботятся потом.
# 2519
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Что такое симулятор? Симулятор - это программа, которая создает звуковые эффекты для улучшения акустического опыта пользователей.
# 532
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое тестовые данные? Это просто информация, которая используется для заполнения форм во время тестирования.
# 594
# ответ: 0* (примечание: ответ 0 1
# Правильность ответа:   0  Correct answer:  0
# Какие существуют предпосылки к тому, что там следует внедрить автоматизацию? Перечислите 4 тезиса. Желание компании создать впечатление о передовости и инновационности за счет использования автоматизации.
# 2547
#  -1
# Правильность ответа:   1  Correct answer:  0
# Назовите критерии качества ПО? Критерии качества ПО:
# 1) функциональность
# 2) эффективность
# 3) надежность
# 4) удобство в использовании
# 5) поддерживаемость
# 6) переносимость
# 7) безопасность
# 8) совместимость
# 584
# ответ: 1*примечание: в тексте  8
# Правильность ответа:   1  Correct answer:  1
# Как мы определяем доли рынка для разных мобильных платформ ? Доли рынка для разных мобильных платформ определяются по количеству лайков и комментариев в социальных сетях.
# 985
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# С чего рекомендуется начинать пункты? (укажите части речи) Начинать пункты рекомендуется с прилагательного или наречия.
# 539
# ответ: 0* (в тексте указано, ч 1
# Правильность ответа:   0  Correct answer:  0
# Что такое универсальные чек-листы? Это чек-листы, которые составляются с учётом всех графических элементов и конкретной реализации проекта.
# 541
# ответ: 0* (источник 1, источни 1
# Правильность ответа:   0  Correct answer:  0
# Что такое архитектура набора команд? Архитектура набора команд (англ. instruction set architecture, ISA) — часть архитектуры компьютера, определяющая программируемую часть ядра микропроцессора.
# 2531
# ответ: 1* (источник: источник  1
# Правильность ответа:   1  Correct answer:  1
# Как мы определяем доли рынка для разных мобильных платформ ? Анализировать рынок с помощью сервисов аналитики.
# 584
# ответ: 1* примечание: в ответе 1
# Правильность ответа:   1  Correct answer:  1
# Что такое архитектура набора команд? Архитектура набора команд - это набор инструкций, которые программисты используют для написания кода на высокоуровневых языках программирования.
# 558
#  -1
# Правильность ответа:   1  Correct answer:  0
# Возможно ли исчерпывающее (полное тестирование)? Полное тестирование возможно для любого проекта, просто нужно потратить на это больше времени и ресурсов.
# 523
# ответ: 0* (источник 1 и источн 1
# Правильность ответа:   0  Correct answer:  0
# Какие этапы включает в себя тестирование? 6 этапов тестирования:
#
# 1) планирование тестирования;
# 2) анализ требований;
# 3) проектирование и реализация тестов;
# 5) создание отчётов о ходе и результатах тестирования;
# 6) оценка качества объекта тестирования.
#
# 569
#  -1
# Правильность ответа:   1  Correct answer:  1
# Что такое матрица совместимости устройств? Матрица совместимости устройств - это просто документ, где перечислены все устройства, на которых тестировалось приложение, без какой-либо дополнительной информации.
# 552
# ответ: 0* (матрица совместимос 1
# Правильность ответа:   0  Correct answer:  0
# Какие бывают статусы в чек листе и что они означают? В чек-листе бывают статусы: "зелёный", "красный", "жёлтый", "синий", "фиолетовый".
# 584
# ответ: 0*примечание: в тексте  1
# Правильность ответа:   0  Correct answer:  0
# Как называется официальный (основной) магазин приложений для устройств Android? App Store
# 445
# ответ: 0* (google play store)  1
# Правильность ответа:   0  Correct answer:  0

# %%
import numpy as np
from sklearn.metrics import f1_score
y_true = data['Correctness']
y_pred = data['Model output_corr']
print(f1_score(y_true, y_pred, average='macro'))
print(f1_score(y_true, y_pred, average='micro'))
print(f1_score(y_true, y_pred, average='weighted'))
print(f1_score(y_true, y_pred, average=None))
# Out:
# 0.6936274509803921
# 0.7333333333333333
# 0.7578431372549019
# [0.80392157 0.58333333]

# %%
data[data['Model output']!=data['Correctness']]
# Out:
#                                               Question  \
# 0    Как называется официальный (основной) магазин ...
# 1    С чего рекомендуется начинать пункты? (укажите...
# 2                   Что такое универсальные чек-листы?
# 3                       Назовите критерии качества ПО?
# 4    Проверки в чек-листе бывают с детализацией по ...
# ..                                                 ...
# 219               Что такое архитектура набора команд?
# 220   Возможно ли исчерпывающее (полное тестирование)?
# 222         Что такое матрица совместимости устройств?
# 223  Какие бывают статусы в чек листе и что они озн...
# 224  Как называется официальный (основной) магазин ...
#
#                                                 Answer  Correctness  \
# 0                                    Google App Center            0
# 1    Пункты должны начинаться с числительного или ч...            0
# 2    Можно использовать для тестирования всех возмо...            0
# 3    Качественное ПО определяется наличием красивых...            0
# 4    Под этим понимается, что в чек-листе указывает...            0
# ..                                                 ...          ...
# 219  Архитектура набора команд - это набор инструкц...            0
# 220  Полное тестирование возможно для любого проект...            0
# 222  Матрица совместимости устройств - это просто д...            0
# 223  В чек-листе бывают статусы: "зелёный", "красны...            0
# 224                                          App Store            0
#
#                     Lesson                                            Comment  \
# 0        process_lection_3  Если студенты отвечают Samsung Galaxy Store ил...
# 1    introduction_lesson_2                                                NaN
# 2    introduction_lesson_2                                                NaN
# 3    introduction_lesson_1   \n \t\nответ считается неверным если не упомя...
# 4    introduction_lesson_2                                                NaN
# ..                     ...                                                ...
# 219      process_lection_2                                                NaN
# 220  introduction_lesson_1                                                NaN
# 222      process_lection_1                                                NaN
# 223  introduction_lesson_2  \nответ считается частично верным если упомяну...
# 224      process_lection_3  Если студенты отвечают Samsung Galaxy Store ил...
#
#      Model output
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ..            ...
# 219             1
# 220             1
# 222             1
# 223             1
# 224             1
#
# [178 rows x 6 columns]

# %%
data.iloc[40:100,:].to_csv

# %%
# This is the part for estimation of the question-answer pair and giving the result - data1 - dataframe with test answers
data_test = pd.read_csv('train_data.csv')
data_test = data_test.iloc[40:100,:]
data_test.to_csv('test_data.csv', index= False)
data_test = pd.read_csv('test_data.csv')
print(data_test.head())
data1 = data_test.copy()
data1['Correctness'] = 0

for i in tqdm(range(len(data1))):
    question, answer, corr = data1.iloc[i, :3]
    print(question, answer)
    reply = respond_question(question)
   # print(reply)
    tmp = reply.replace('\n','').lower()
    start = tmp.find('ответ:')
    print(tmp[start:start+30], start)
    start = tmp.find('*', start+1)
    end = start
    output = tmp[end-2:end]
    print('Правильность ответа: ', output, ' Correct answer: ', corr)
    data1.loc[i, 'Model output'] = output
data_final = data1.copy()
data_final['Model output_corr'] = [1 if '1' in row else 0 for row in data_final['Model output']]

submission = pd.read_csv('sample_submission.csv')
submission.hash = 0
submission['Correctness'] = data_final['Model output_corr']
submission.to_csv('submission_gb.csv', index= False)
# Out:
#                                             Question  \
# 0          Что такое гибридные мобильные приложения?
# 1                       Что такое связнный чек лист?
# 2         Что такое матрица совместимости устройств?
# 3  Какие существуют предпосылки к тому, что там с...
# 4  Как называется официальный магазин приложений ...
#
#                                               Answer  Correctness  \
# 0  Гибридные мобильные приложения - это приложени...            0
# 1  Это чек-лист, где каждая проверка зависит от в...            0
# 2  Это документ, который содержит информацию толь...            0
# 3  Существует несколько предпосылок к тому, когда...            1
# 4                                  Google Play Store            0
#
#                   Lesson                                            Comment
# 0      process_lection_1                                                NaN
# 1  introduction_lesson_2                                                NaN
# 2      process_lection_1                                                NaN
# 3      process_lection_1  Если упомянуто менее 3/4 видов тестирования - ...
# 4      process_lection_3                                                NaN
#   0%|          | 0/60 [00:00<?, ?it/s]
# Что такое гибридные мобильные приложения? Гибридные мобильные приложения - это приложения, которые могут менять свои функции в зависимости от того, кто их использует.
# 940
# ответ: 0* (неправильное высказ 1
# Правильность ответа:   0  Correct answer:  0
# Что такое связнный чек лист? Это чек-лист, где каждая проверка зависит от всех предыдущих, и если хоть одна проверка не пройдена, весь чек-лист считается не пройденным.
# 597
# ответ: 0* (связанный чек-лист  1
# Правильность ответа:   0  Correct answer:  0
# Что такое матрица совместимости устройств? Это документ, который содержит информацию только о совместимости устройств с определенными программами, но не о том, как проводить тестирование.
# 2498
#  -1
# Правильность ответа:   1  Correct answer:  0
# Какие существуют предпосылки к тому, что там следует внедрить автоматизацию? Перечислите 4 тезиса. Существует несколько предпосылок к тому, когда нам следует внедрять автоматизацию тестирования.
# 1) Цикл тестирования приложения становится всё больше с каждым разом
# 2) Увеличение внутреннего парка мобильных устройств
# 3) Большое количество регрессионных тестов
# 4) Поддержка большого числа версий операционных систем
#
# 590
#  -1
# Правильность ответа:   1  Correct answer:  0
# Как называется официальный магазин приложений для устройств Apple? Google Play Store
# 430
# ответ: 0* (app store) источник 1
# Правильность ответа:   0  Correct answer:  0
# Как называется официальный (основной) магазин приложений для устройств Android? Google Play Store
# 471
# ответ: 1* (источник 2 и источн 1
# Правильность ответа:   1  Correct answer:  0
# Перечислите типичные виды, которые применяются в мобильном тестировании? Исследование влияния цветовой гаммы на эмоциональное состояние пользователя.
# 521
# ответ: 0* (нет информации о ти 1
# Правильность ответа:   0  Correct answer:  0
# Какую информацию хранит раздел App Bundle Explorer в Google Play Console? Историю покупок в Google Play Store
# 533
# ответ: 0* (в разделе app bundl 1
# Правильность ответа:   0  Correct answer:  0
# Что такое эмулятор? Эмулятор - это человек, который воспроизводит действия и поведение реального пользователя для тестирования приложений.
# 499
#  -1
# Правильность ответа:   1  Correct answer:  0
# Какие этапы включает в себя тестирование? Тестирование включает в себя следующие этапы: установка программы и удаление её, потому что она не работает.
# 2518
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое Xcode? Xcode — это IDE (Integrated Development Environment, «интегрированная среда разработки»), созданная для разработки iOS-приложений.
# 908
# ответ:xcode — это ide (integra 1334
# Правильность ответа:  pd  Correct answer:  0
# Что такое TestFlight? Место для публикации мобильного приложения
# 527
# ответ: 0* источники:источник 1 375
# Правильность ответа:   0  Correct answer:  0
# С чего рекомендуется начинать пункты? (укажите части речи) Пункты всегда начинаются с предлога или местоимения.
# 531
# ответ: 0* (источник 1 и источн 1
# Правильность ответа:   0  Correct answer:  0
# Перечислите типичные виды, которые применяются в мобильном тестировании? Определение скорости, с которой мобильное устройство может вращаться на 360 градусов.
# 605
# ответ: 0* примечание: в тексте 1
# Правильность ответа:   0  Correct answer:  0
# Что такое Xcode? Это полный набор программного обеспечения, и с его помощью разработчики могут выполнять множество задач, таких как проектирование пользовательского интерфейса, разработка кода для приложений, компиляция и тестирование кода, а также проверка наличия ошибок в коде.
# 2526
# ответ: 1* (источник 1, источни 1
# Правильность ответа:   1  Correct answer:  0
# Зачем нужны сервисы дистрибуции мобильных приложений? Они используются для того, чтобы улучшить цветовую гамму приложений и сделать их более привлекательными для пользователей.
# 575
# ответ: 0* обоснование: в текст 1
# Правильность ответа:   0  Correct answer:  0
# Что такое тестовые данные? Это просто данные, которые тестировщики придумывают сами, без каких-либо стандартов или требований.
# 751
# ответ: 0* (примечание: ответ 0 1
# Правильность ответа:   0  Correct answer:  0
# Какие бывают статусы в чек листе и что они означают? 1) passed — успешно пройден
# 2) failed — кейс не прошел проверку
# 3) skipped — пропуск проверки
# 4 blocked — проверка заблокирована
# 5) untested — кейс еще не брали в работу
# 686
# ответ: 1*примечание: в источни 8
# Правильность ответа:   1  Correct answer:  0
# Какие этапы включает в себя тестирование? Этапы тестирования: собрать команду из любителей видеоигр, дать им пять минут, чтобы понять, что программа не игра, и затем переключиться на другую задачу.
# 941
# ответ: 0* (нет информации о эт 1
# Правильность ответа:   0  Correct answer:  0
# Что такое тестирование програмного обеспечения? Дайте полное определение. Тестирование программного обеспечения - это бесполезная трата времени и ресурсов.
# 546
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое гибридные мобильные приложения? Это приложения для конкретной платформы. Разрабатываются с помощью SDK, инструментов разработки, датчиков и функций конкретных платформ.
#
# 535
# ответ: 0* (неправильное высказ 1
# Правильность ответа:   0  Correct answer:  0
# Что такое крешлоги? Крэшлоги — это данные о том, что происходило с приложением в момент сбоя, а также данные о разделе приложения, в котором произошёл сбой.
# 524
# ответ: 1* (примечание: в ответ 1
# Правильность ответа:   1  Correct answer:  0
# С чего рекомендуется начинать пункты? (укажите части речи) С существительного
# 458
#  -1
# Правильность ответа:  pd  Correct answer:  0
# Что такое эмулятор? Эмулятор - это устройство, которое используется для эмуляции погодных условий внутри помещения.
# 542
# ответ: 0* примечание: эмулятор 1
# Правильность ответа:   0  Correct answer:  0
# Как называется официальный (основной) магазин приложений для устройств Android? Android Market
# 450
# ответ: 0* (google play store,  1
# Правильность ответа:   0  Correct answer:  0
# Что такое ферма устройств? Это место, где производят выращивание овощей и фруктов с использованием специальных агротехнологий.
# 534
# ответ: 0* (нет информации о фе 1
# Правильность ответа:   0  Correct answer:  0
# На чем может проводиться тестирование мобильных приложений? Тестирование мобильных приложений может проводиться на компьютерах с установленными эмуляторами и симуляторами.
# 802
# ответ: 0* (нет информации о те 1
# Правильность ответа:   0  Correct answer:  0
# Назовите цели тестирования. Цели тестирования:
# 1) определить, насколько ПО соответствует заявленным требованиям;
# 2) выявить дефекты, то есть отклонения ПО от требований.
#
# 507
#  -1
# Правильность ответа:   1  Correct answer:  0
# Что такое универсальные чек-листы? Для универсального чек-листа составляется абстрактный список проверок.
# 666
# ответ: 1* (источник 1, источни 1
# Правильность ответа:   1  Correct answer:  0
# Как мы определяем доли рынка для разных мобильных платформ ? Определять доли рынка для разных мобильных платформ можно по количеству проданных на рынке ноутбуков
# 604
#  -1
# Правильность ответа:   1  Correct answer:  0
# Подходят ли эмулятор и симулятор для отладки приложения? Эмулятор больше подходит для отладки. Симулятор в меньшей степени подходит для отладки.
# 690
# ответ: 1* обоснование: в источ 1
# Правильность ответа:   1  Correct answer:  0
# На основе какого документа составляют чек-листы? Чек-листы создаются на основе прошлых ошибок, чтобы каждый раз повторять одни и те же тесты.

# %%
submission = pd.read_csv('sample_submission.csv')
submission
# Out:
#                    hash  Correctness
# 0  -7414006047293242141            0
# 1   3210987722203522575            0
# 2  -6393407802773951698            0
# 3   4883083763232971429            0
# 4  -7928633508113063601            0
# ..                  ...          ...
# 71  4048903089355147400            0
# 72  1491295277717010652            0
# 73 -8366699346511237760            0
# 74 -8599528935261139553            0
# 75 -6391278208555238239            0
#
# [76 rows x 2 columns]
